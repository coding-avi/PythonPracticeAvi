# %%
name = "avi"
learning = "python"

# %%
fruits =["apple","orange","mango","strawberry"]
# access
# change data
print(fruits[2])

# can you print apple please
print(fruits[0])

fruits[0] = "pears"
print(fruits)

fruits[3] = "kiwi"
print(fruits)


## add new data
fruits.append("apple")
fruits.append("apple")
print(fruits)



fruits.remove("apple")
print(fruits)
# Out:
# mango
# apple
# ['pears', 'orange', 'mango', 'strawberry']
# ['pears', 'orange', 'mango', 'kiwi']
# ['pears', 'orange', 'mango', 'kiwi', 'apple', 'apple']
# ['pears', 'orange', 'mango', 'kiwi', 'apple']

# %%
for each in fruits:
    print(f"i like {each}")
# Out:
# i like pears
# i like orange
# i like mango
# i like kiwi
# i like apple

# %%
# please make a list of your friends and send them invitation for dinner ( example )
# hi Sam! you are invited to dinner

# hint: make a list, and run a loop and print
freinds = ["luke","daniel","evan","aaron","alexander"]

for each in freinds:
    print(f" hey {each} you are invited to the dinner. Please dont be late")
# Out:
#  hey luke you are invited to the dinner. Please dont be late
#  hey daniel you are invited to the dinner. Please dont be late
#  hey evan you are invited to the dinner. Please dont be late
#  hey aaron you are invited to the dinner. Please dont be late
#  hey alexander you are invited to the dinner. Please dont be late

# %%
import random

# %%
# please make a list of any 10 words ( size should be more than 4)
words = ["hello","nothing","why","alright","no","yes","mind","muscle","me","you"]
# 

choice = random.choice(words)
print("_,"*len(choice))

avi = input("please enter the possible word: ")


if avi==choice:
    print("you guessed it")
else:
    print("sorry try again")

print(f"the word is {choice}")
# Out:
# _,_,_,_,_,_,
# sorry try again
# the word is muscle

# %%
# guessing game based on numbers

numbers = [1,2,3]
nn = random.choice(numbers)
user = int(input("pleawse enter from 1 2 or 3"))
if user == nn:
    print("you guessed it")
else:
    print("Sorry you could nto guess")
# Out:
# you guessed it
