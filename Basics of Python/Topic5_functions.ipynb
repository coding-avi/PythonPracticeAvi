# %%
x = 100
y = 200

print(f"the sum of {x} and {y} is {x+y}")
print(f"the diff of {x} and {y} is {x-y}")
print(f"the prod of {x} and {y} is {x*y}")
# Out:
# the sum of 100 and 200 is 300
# the diff of 100 and 200 is -100
# the prod of 100 and 200 is 20000

# %%
x = 20
y = 40

print(f"the sum of {x} and {y} is {x+y}")
print(f"the diff of {x} and {y} is {x-y}")
print(f"the prod of {x} and {y} is {x*y}")
# Out:
# the sum of 20 and 40 is 60
# the diff of 20 and 40 is -20
# the prod of 20 and 40 is 800

# %%
def cal(x,y):
    print(f"the sum of {x} and {y} is {x+y}")
    print(f"the diff of {x} and {y} is {x-y}")
    print(f"the prod of {x} and {y} is {x*y}")

# %%
cal(100,200)
# Out:
# the sum of 100 and 200 is 300
# the diff of 100 and 200 is -100
# the prod of 100 and 200 is 20000

# %%
cal(20,30)
# Out:
# the sum of 20 and 30 is 50
# the diff of 20 and 30 is -10
# the prod of 20 and 30 is 600

# %%
from fun import greeting


greeting("Avi")
# Out:
# heyyy Avi! welcome to class

# %%
greeting("umair")
# Out:
# heyyy umair! welcome to class

# %%
from fun import age1

# %%
import random 
age1(99)
# Out:
# you can apply for driving license

# %%
age1(11)
# Out:
# sorry you are too young

# %%
def guess(trials):
    game = input("game:? ")

    for i in range(trials):
        human = input("choose rock paper or scissors")
        options = ["rock", "paper", "scissors"]
        computer = random.choice(options)

        print(f"{game} chooses {human}")
        print(f"computer choose {computer}")


        if human == computer:
            print("draw")
        elif human == "paper" and computer =="rock" or human =="rock" and computer=="scissors" or human=="scissor" and computer =="paper":
            print(f"{game} won")

        else:
            print("computer won!")

# %%
guess(10)
# Out:
# d chooses d
# computer choose rock
# computer won!
# d chooses d
# computer choose rock
# computer won!
# d chooses d
# computer choose rock
# computer won!
# d chooses d
# computer choose rock
# computer won!
# d chooses d
# computer choose scissors
# computer won!
# d chooses d
# computer choose paper
# computer won!
# d chooses d
# computer choose paper
# computer won!
# d chooses d
# computer choose paper
# computer won!
# d chooses d
# computer choose paper
# computer won!
# d chooses d
# computer choose scissors
# computer won!
