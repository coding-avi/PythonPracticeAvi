# %%
fruits = ["apple", "banana", "cherry", "date", "elderberry"]
colors = ["red", "yellow", "red", "brown", "purple"]

fruits = {"apple": "red", "banana": "yellow", "cherry": "red", "date": "brown"}

# %%
print(fruits.keys())
print(fruits.values())
# Out:
# dict_keys(['apple', 'banana', 'cherry', 'date'])
# dict_values(['red', 'yellow', 'red', 'brown'])

# %%
fruitsS_prices = {"apple": 0.5, "banana": 0.3, "cherry": 0.2, "date": 0.4, "elderberry": 0.6}

# %%
prices = [
    {"apple": 0.5, "banana": 0.3, "cherry": 0.2},
    {"date": 0.4, "elderberry": 0.6}
]

# %%
# please make a dictionary with animal names and their legs

# %%
animals = {"dog": 4, "cat": 4, "spider": 8, "human": 2, "ant": 6}

# %%
# 3make a dictionary with country name and their population

# %%
country_population = {"USA": 331000000, "India": 1380000000, "China": 1430000000, "Brazil": 212000000, "Nigeria": 206000000}

# %%
# make a list with top 5 football players

# %%
players = ["Lionel Messi", "Cristiano Ronaldo", "Neymar Jr.", "Kylian Mbappé", "Kevin De Bruyne"]

# %%
# make a list of top 5 programming languages

# %%
topefiveprograminglanguages = ["Python", "JavaScript", "Java", "C#", "C++"]

# %%
# now combine list and dictionary in such a way to show shop1 fruits price and shop2 fruits price and also show the total price of fruits in shop1 and shop2

# %%
shops = [
    {"apple": 0.5, "banana": 0.3, "cherry": 0.2},
    {"apple": 0.6, "banana": 0.4, "cherry": 0.3},
    {"date": 0.4, "elderberry": 0.6}
]

# %%
# for usa write population of any 5 states and cities in that state

# %%
usa_population = {
    "California": {"Los Angeles": 4000000, "San Francisco": 880000},
    "Texas": {"Houston": 2300000, "Dallas": 1300000},
    "Florida": {"Miami": 470000, "Orlando": 290000},
    "New York": {"New York City": 8500000, "Buffalo": 260000},
    "Illinois": {"Chicago": 2700000, "Aurora": 210000}
}

# %%
# write a dictionary with 5 car brands and their models

# %%
carbrands = {
    "Toyota": ["Camry", "Corolla", "Prius"],
    "Honda": ["Civic", "Accord", "CR-V"],
    "Ford": ["F-150", "Mustang", "Explorer"],
    "BMW": ["3 Series", "5 Series", "X3"],
    "Audi": ["A4", "A6", "Q5"]
}

# %%
google_locations = {
    "Mountain View": {"address": "1600 Amphitheatre Parkway, Mountain View, CA 94043", "employees": 10000, "axis": [0, 1]},
    "New York": {"address": "111 8th Avenue, New York, NY 10011", "employees": 5000},
    "London": {"address": "Belgrave House, 76 Buckingham Palace Rd, London SW1W 9TQ, UK", "employees": 3000},
    "Sydney": {"address": "48 Pirrama Rd, Pyrmont NSW 2009, Australia", "employees": 2000},
    "Tokyo": {"address": "6-10-1 Roppongi, Minato City, Tokyo 106-6126, Japan", "employees": 4000}
}
