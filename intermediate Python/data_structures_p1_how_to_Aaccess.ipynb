# %%
fruits = ["apple", "banana", "orange", "grape"  , "kiwi"]

# %%
fruits[2]
# Out:
# 'orange'

# %%
fruits[4]
# Out:
# 'kiwi'

# %%
colors = ["red", "green", "blue", "yellow", "purple", "orange", "pink", "brown", "bcolk", "white"]
colors[-1]
# Out:
# 'white'

# %%
colors[-3]
# Out:
# 'brown'

# %%
names = ["Alice", "Bob", "Charlie", "David", "Eve", "Frank", "Grace", "Heidi", "Ivan", "Judy", "Karl", "Leo", "Mallory", "Nina", "Oscar", "Peggy", "Quentin", "Rupert", "Sybil", "Trent", "Uma", "Victor", "Walter", "Xavier","AVI", "Yvonne", "Zara"]

# %%
names[-3]
# Out:
# 'AVI'

# %%
groceries = [["milk", "bread", "eggs"], ["apples", "oranges", "bananas"], ["chicken", "beef", "fish"]]

# %%
groceries[0][2]
# Out:
# 'eggs'

# %%
names = [["Alice", "Bob", "Charlie"], ["David", "Eve", "Frank"], ["umair","'avi"],["Grace", "Heidi", "Ivan"]]

# %%
names[2][1]
# Out:
# "'avi"

# %%
names = ["Alice", "Bob", "Charlie", "David", "Eve" ,["apple", "banana", "orange"], ["red","'avi", "green", "blue"]]

# %%
names[6][__annotations__]
# Out:
# ['red', "'avi", 'green', 'blue']
