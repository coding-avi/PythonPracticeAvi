# %%
colors = ["red", "green", "blue"]
fruits = ["apple", "banana", "cherry"]

# %%
# make a dctionary
c_f = {
    "red"   : "apple",
    "green" : "banana",
    "blue"  : "cherry"
}

# %%
for a,b in c_f.items():
    print(f"{a} is the color of {b}")
# Out:
# red is the color of apple
# green is the color of banana
# blue is the color of cherry

# %%
# please make 5 country names and their population in a dictionary

# %%
countries_population = {
    "India" : 1_400_000_000,   
    "China" : 1_400_000_000,
    "United States" : 331_000_000,
    "Indonesia" : 273_000_000,
    "Pakistan" : 220_000_000
}
for country, population in countries_population.items():
    print(f"{country} has a population of {population}")
# Out:
# India has a population of 1400000000
# China has a population of 1400000000
# United States has a population of 331000000
# Indonesia has a population of 273000000
# Pakistan has a population of 220000000

# %%
# make a new dictionary with student name and their marks in a subject

# %%
student_marks = {
    "Alice" : 85,
    "Bob" : 90,
    "Charlie" : 78,
    "Diana" : 95,
    "Eve" : 88

}

# %%
# now we add a new country to the contries_population dictionary

# %%
countries_population["Brazil"] = 212_000_000

# %%
print(countries_population)
# Out:
# {'India': 1400000000, 'China': 1400000000, 'United States': 331000000, 'Indonesia': 273000000, 'Pakistan': 220000000, 'Brazil': 212000000}

# %%
student_marks = {
    "Alice" : 85, 
    "Bob" : 90,
    "Charlie" : 78,
    "Diana" : 95,
    "Eve" : 88,
    "frank" : 92
}

# %%
student_marks['umair'] = 91

# %%
student_marks["ali"] = 89

# %%
student_marks["Grace"] = 89

# %%
student_marks
# Out:
# {'Alice': 85,
#  'Bob': 90,
#  'Charlie': 78,
#  'Diana': 95,
#  'Eve': 88,
#  'frank': 92,
#  'umair': 91,
#  'ali': 89,
#  'Grace': 89}

# %%
# we make a dictionary of moviess and their ratings ( according to your interest)

# %%
movie_ratings = {
    "Inception" : 8.8,
    "The Dark Knight" : 9.0,
    "Pulp Fiction" : 8.9,
    "Forrest Gump" : 8.8
}

# %%
movie_ratings["The Matrix"] = 8.7

# %%
movie_ratings
# Out:
# {'Inception': 8.8,
#  'The Dark Knight': 9.0,
#  'Pulp Fiction': 8.9,
#  'Forrest Gump': 8.8,
#  'The Matrix': 8.7}

# %%
del movie_ratings["Pulp Fiction"]

# %%
movie_ratings
# Out:
# {'Inception': 8.8,
#  'The Dark Knight': 9.0,
#  'Forrest Gump': 8.8,
#  'The Matrix': 8.7}

# %%
del movie_ratings["The Dark Knight"]

# %%
movie_ratings
# Out:
# {'Inception': 8.8, 'Forrest Gump': 8.8, 'The Matrix': 8.7}

# %%
del movie_ratings["Inception"]

# %%
movie_ratings["the avengers"] = 8.0

# %%
movie_ratings
# Out:
# {'Forrest Gump': 8.8, 'The Matrix': 8.7, 'the avengers': 8.0}

# %%
movie_ratings["The Matrix 2"] = 8.7

# %%
movie_ratings
# Out:
# {'Forrest Gump': 8.8,
#  'The Matrix': 8.7,
#  'the avengers': 8.0,
#  'The Matrix 2': 8.7}

# %%
# please make a demo data for patients and their body temperature
patients_temperature = {
    "John Doe" : 98.6,
    "Jane Smith" : 99.1,
    "Alice Johnson" : 97.8,
    "Bob Brown" : 100.2,
    "Charlie Davis" : 98.4,
    "david wilson" : 99.5,
    "Emily Clark" : 98.9,
    "frank thomas" : 101.3,
    "Grace Lee" : 98.7,
}

# %%
for name, temp in patients_temperature.items():
    if temp > 99.0:
        print(f"{name} has fever ")
    else:
        print(f"{name} is healthy")
# Out:
# John Doe is healthy
# Jane Smith has fever
# Alice Johnson is healthy
# Bob Brown has fever
# Charlie Davis is healthy
# david wilson has fever
# Emily Clark is healthy
# frank thomas has fever
# Grace Lee is healthy
